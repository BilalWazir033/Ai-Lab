# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
if 10>5:
    print("Ten is greater than five") # indentation
    """
    we are with you
    """
# Out:
# Ten is greater than five

# %%
print("We are with you")
'''
we are with you
'''
# Out:
# We are with you
# '\nwe are with you\n'

# %%
def add(a, b):
    """
    This function adds two numbers
    and returns the result
    """
    # Perform addition
    return a + b
print(add(12,23))
# Out:
# 35

# %%
a=34
b=33.5
name="Ali"
x=True 

def addition(a,b):
    return a+b
print(name," scores: ",addition(a,b))
print(type(a))
print(type(b))
print(type(name))
print(type(x))
# Out:
# Ali  scores:  67.5
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
x,y,z="apple","banana","carrot"
a=b=c="Milk"
print(x,y,z)
print(y)
print(a)
print(c)
# Out:
# apple banana carrot
# banana
# Milk
# Milk

# %%
input("Enter your name:")
name=input("Enter your age:")
print(name)
int(input("Enter your age:"))
# Out:
# Enter your name: Alim 23
# Enter your age: 23 years
# 23 years
# Enter your age: 32
# 32

# %%
x=str(3)
print(x)
print(type(x))
x=float(3)
print(x)
print(type(x))
# Out:
# 3
# <class 'str'>
# 3.0
# <class 'float'>

# %%
sum([45,64])
a,b=4,46
result=a+b
print(result)
print(a+b)
# Out:
# 50
# 50
# 1j

# %%
x=23+45j
print(x)
y=45j
print(y)
# Out:
# (23+45j)
# 45j

# %%
a='nadeem'
print(a)
b="whaeed"
print(b)
# Out:
# nadeem
# whaeed

# %%
a="""
This my first program
we will enjoy
"""
print(a)
# Out:
# This my first program
# we will enjoy

# %%
a="Haroon Ur Rashid"
print(a[2:8])
print(a[2])
# Out:
# roon U
# r

# %%
for x in "Ashwin":
    print(x)
for i in range(7):
    print("Hello World")
# Out:
# A
# s
# h
# w
# i
# n
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
a="""
This my first program
we will enjoy
"""
print(len(a))
a="HaroonUrRashid"
y="Hazrat Bilal"
print(len(a),len(y))
# Out:
# 37
# 14 12

# %%
a="""
This my first program
we will enjoy
"""
if "where" in a:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
b="University"
print(b[-7:-1])
# Out:
# versit

# %%
a="""
        This my first program
we will enjoy     
"""
print(a.upper())
print(a.lower())
print(a.strip()) # removel of white spaces before and after text
print(a.replace(" ",""))# removel of white spaces in between the text
print(a.replace("enjoy","celebrate"))# replace one word with another
# Out:
#         THIS MY FIRST PROGRAM
# WE WILL ENJOY
#
#
#         this my first program
# we will enjoy
#
# This my first program
# we will enjoy
#
# Thismyfirstprogram
# wewillenjoy
#
#
#         This my first program
# we will celebrate

# %%
a="Hello, World, Me, We, Are"
print(a.split(","))
print(a)
# Out:
# ['Hello', ' World', ' Me', ' We', ' Are']
# Hello, World, Me, We, Are

# %%
a="Haroon"
b="Ur"
c="Rashid"
d=a+b+c
print(d)
print(a+b+c)
# Out:
# HaroonUrRashid
# HaroonUrRashid

# %%
age=24
txt="Haroon is {} years old."
print(txt.format(age))
# Out:
# Haroon is 24 years old.

# %%
print(10>12)
print(20>12)
print(40==40)
print(23<30)
# Out:
# False
# True
# True
# True

# %%
#14.1
x="lsl"
print(bool(x))
y=0
print(bool(y))
# Out:
# True
# False

# %%
#15
a=20
b=6
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 3.3333333333333335
# 3
# 2
# 64000000

# %%
import math
a=20
b=6
print(math.ceil(a/b))
# Out:
# 4

# %%
#15.6 identity operator
x=5
y=5 # x=y
print(x is y)
print(x is not y)
# Out:
# True
# False

# %%
#16.7 Membership Operator
z=7
x=5
y=[23,5,65,75]
print(z in y)
print(x in y)
# Out:
# False
# True

# %%
#15.8 Bitwise Operator
a = 5   # 0101
b = 3   # 0011

print("AND (&):", a & b)     # 1
print("OR (|):", a | b)      # 7
print("XOR (^):", a ^ b)     # 6
print("NOT (~):", ~a)        # -6
print("Left Shift (<<):", a << 1)   # 10
print("Right Shift (>>):", a >> 1)  # 2
# Out:
# AND (&): 1
# OR (|): 7
# XOR (^): 6
# NOT (~): -6
# Left Shift (<<): 10
# Right Shift (>>): 2

# %%
#list 16
lang=["Arabic", "Persian", "Pashto"]
print(len(lang))
print(lang[1])
# Out:
# 3
# Persian

# %%
#16.3 list constructor
details=list((23,"bilal", 25.4))
print(details)
print(details[2])
print(details[-3])
details[1]="Imran"
print(details)
fruits=["orange", "apple", "mango", "carrot", "watermellon"]
print(fruits)
fruits.sort()
print(fruits)
# Out:
# [23, 'bilal', 25.4]
# 25.4
# 23
# [23, 'Imran', 25.4]
# ['orange', 'apple', 'mango', 'carrot', 'watermellon']
# ['apple', 'carrot', 'mango', 'orange', 'watermellon']

# %%
# 17 Tuples 
vegitable=("onion", "potato", "agile")
print(vegitable)
# Out:
# ('onion', 'potato', 'agile')

# %% [markdown]
# # 18 Sets
# animal={"cat", "dog", "elemphant"}
# print(animal)

# %%
#sets
animal={"cat", "dog", "elemphant"}
print(animal)
# Out:
# {'elemphant', 'dog', 'cat'}

# %%
# dictionaries
student={
    "name": "Ahmad",
    "Age": 23,
    "Grade": "A"
}
print(student)
# Out:
# {'name': 'Ahmad', 'Age': 23, 'Grade': 'A'}

# %%
x=20
y=34

if x>y:
    print("You are my friend")
elif x==y: 
    print("You are girlfriend")
else:
    print("you are not my friend")


print("Friend") if x>y else print("Not friend")
# Out:
# you are not my friend
# Not friend

# %%
i=1
while i<5:
    print("Me")
    i+=1
# Out:
# Me
# Me
# Me
# Me

# %%
i=1
while i<5:
    print("Me")
    if i==2:
        break
    i+=1
# Out:
# Me
# Me

# %%
fruits=["orange", "apple", "mango", "carrot", "watermellon"]
for i in fruits:
    print(i)

print(fruits)
# Out:
# orange
# apple
# mango
# carrot
# watermellon
# ['orange', 'apple', 'mango', 'carrot', 'watermellon']

# %%
for x in "banana":
    print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
fruits=["orange", "apple", "mango", "carrot", "watermellon"]
for i in fruits:
    if i=="carrot":
        continue
    print(i)
# Out:
# orange
# apple
# mango
# watermellon

# %%
fruits=["orange", "apple", "mango", "carrot", "watermellon"]
