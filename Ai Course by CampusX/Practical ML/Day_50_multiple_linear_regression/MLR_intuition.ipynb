# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.express as px

# %%
# making self dataset
X,y=make_regression(n_samples=100,n_features=2,n_informative=2,n_targets=1,noise=50) # sample total rows, n_features input cols, n_targets target cols

# %%
# converting to dataframe
df=pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})

# %%
df.head()
# Out:
#    feature1  feature2     target
# 0 -0.931028 -0.098283 -57.982079
# 1 -0.061496  0.569331  10.124891
# 2  0.709128  1.868555  86.050869
# 3  0.199234  0.315674 -13.367051
# 4  0.773190  0.830475  48.537271

# %%
df.shape
# Out:
# (100, 3)

# %%
fig=px.scatter_3d(df,x='feature1',y='feature2',z='target')
fig.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lr.predict(X_test)

# %%
y_predict
# Out:
# array([   9.82458783,  -48.79903622, -102.16535303,  -63.28000987,
#          82.02229981, -145.49175867,   75.93256812,   47.79777184,
#         125.80323111,   54.92812093,  176.53983782,  145.48775814,
#         -43.04661028,  -35.40780929,  218.94786071,   45.56814791,
#          57.10714913,   -3.27757965, -126.88417862,  -48.61424633])

# %%
from sklearn.metrics import accuracy_score,mean_absolute_error,mean_squared_error,r2_score

# %%
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None)
# Out:
# LinearRegression()

# %%
mae=mean_absolute_error(y_test,y_predict)
mse=mean_squared_error(y_test,y_predict)
r2=r2_score(y_test,y_predict)

# %%
print(f'MAE: {mae}, MSE: {mse}, R2: {r2}')
# Out:
# MAE: 38.45155035781665, MSE: 1728.8393470632413, R2: 0.8500763879608723

# %%
import plotly.graph_objects as go

# %%
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)

xGrid, yGrid = np.meshgrid(x, y)

# Create all combinations of x and y
final = np.vstack((
    xGrid.ravel(),
    yGrid.ravel()
)).T

# Predict z values
z_final = lr.predict(final).reshape(10, 10)

z = z_final

# Original data points
fig = px.scatter_3d(
    df,
    x='feature1',
    y='feature2',
    z='target'
)

# Regression plane
fig.add_trace(
    go.Surface(
        x=x,
        y=y,
        z=z
    )
)

fig.show()

# %%
# Import NumPy for numerical operations
import numpy as np

# Import Plotly Express for creating the 3D scatter plot
import plotly.express as px

# Import Plotly Graph Objects for creating the regression surface/plane
import plotly.graph_objects as go


# Create 10 equally spaced values between -5 and 5 for feature 1
x = np.linspace(-5, 5, 10)

# Create 10 equally spaced values between -5 and 5 for feature 2
y = np.linspace(-5, 5, 10)


# Create a grid of x and y values
# This generates all possible combinations of x and y
xGrid, yGrid = np.meshgrid(x, y)


# Convert the grid values into a list of (x, y) pairs
# ravel() converts the 2D arrays into 1D arrays
# vstack() combines x and y values
# .T transposes the result so each row becomes [x, y]
final = np.vstack((
    xGrid.ravel(),
    yGrid.ravel()
)).T


# Use the trained Linear Regression model to predict
# the target value for every (x, y) combination
z_final = lr.predict(final)


# Convert the predicted values into a 10 x 10 matrix
# so they can be used to create the 3D surface
z_final = z_final.reshape(10, 10)


# Store the predicted z values in variable z
z = z_final


# Create a 3D scatter plot using the original dataset
# feature1 → X-axis
# feature2 → Y-axis
# target   → Z-axis
fig = px.scatter_3d(
    df,
    x='feature1',
    y='feature2',
    z='target'
)


# Add the Linear Regression prediction surface/plane
# x and y represent the two input features
# z represents the predicted target values
fig.add_trace(
    go.Surface(
        x=x,
        y=y,
        z=z
    )
)


# Display the final 3D graph
fig.show()

# %%
lr.coef_
# Out:
# array([88.54618279, 29.27132797])

# %%
lr.intercept_
# Out:
# np.float64(5.0401426611685585)

# %%
git add .
git commit -m "Added multiple linear regression intuition notebook with 3D visualization"
git push origin main
