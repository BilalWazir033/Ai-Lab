# %%
# Cell: 01
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cell: 02
pd.set_option('display.max_columns', None) #None tells pandas: “Do not limit the number of rows displayed.”
pd.set_option('display.max_rows', 10)

# %%
# Cell: 03
dataset = pd.read_csv('38_ev_range.csv')

# %%
# Cell: 04
dataset.head()
# Out:
#   manufacturer vehicle_type charging_type_last drive_config battery_chemistry  \
# 0      Hyundai          NaN       Supercharger          FWD               LFP
# 1        Tesla   Sports Car           Wireless          AWD               NCA
# 2          BMW        Truck     DC Fast Charge          FWD       Solid State
# 3          NIO    Crossover           Wireless          AWD               NMC
# 4          NIO    Crossover                NaN          FWD               NMC
#
#    model_year  battery_capacity_kwh  battery_age_years  battery_health_pct  \
# 0      2024.0                  62.9                NaN                98.3
# 1      2024.0                  49.9                2.0                79.0
# 2      2015.0                  29.6                6.0                73.0
# 3      2021.0                  65.5                2.0                87.2
# 4      2021.0                 127.1                NaN                78.9
#
#    motor_power_kw  vehicle_weight_kg  drag_coefficient  \
# 0             NaN                NaN             0.305
# 1           679.0             1455.0             0.306
# 2           455.0                NaN             0.329
# 3             NaN             3812.0             0.433
# 4           222.0             1842.0             0.434
#
#                 tire_type  ambient_temp_c hvac_usage  avg_speed_kmh  \
# 0  Low Rolling Resistance            38.1   Max Heat            NaN
# 1  Low Rolling Resistance            -6.8   Max Heat           98.2
# 2                Standard            13.7    Heating          123.1
# 3             All-Terrain            -1.6   Max Cool            NaN
# 4  Low Rolling Resistance             NaN    Heating           55.3
#
#    elevation_change_m  num_passengers  cargo_weight_kg regenerative_braking  \
# 0               349.9             NaN            270.0                  Off
# 1               337.9             1.0            471.0                  NaN
# 2                65.7             2.0              NaN                 High
# 3                 NaN             5.0             45.0                  Off
# 4              -248.0             3.0            169.0                  Off
#
#   driving_mode  wind_speed_kmh  actual_range_km
# 0        Chill             NaN            499.9
# 1        Chill            50.0            328.2
# 2     Off-Road            60.5            421.7
# 3        Sport            21.2            647.8
# 4     Off-Road            39.0            527.3

# %%
# Cell: 05
dataset.columns
# Out:
# Index(['manufacturer', 'vehicle_type', 'charging_type_last', 'drive_config',
#        'battery_chemistry', 'model_year', 'battery_capacity_kwh',
#        'battery_age_years', 'battery_health_pct', 'motor_power_kw',
#        'vehicle_weight_kg', 'drag_coefficient', 'tire_type', 'ambient_temp_c',
#        'hvac_usage', 'avg_speed_kmh', 'elevation_change_m', 'num_passengers',
#        'cargo_weight_kg', 'regenerative_braking', 'driving_mode',
#        'wind_speed_kmh', 'actual_range_km'],
#       dtype='object')

# %%
# Cell: 06
dataset.describe()
# Out:
#         model_year  battery_capacity_kwh  battery_age_years  \
# count   828.000000            828.000000         846.000000
# mean   2019.508454             75.437319           4.477541
# std       2.917848             31.727757           2.913562
# min    2015.000000             20.000000           0.000000
# 25%    2017.000000             48.175000           2.000000
# 50%    2020.000000             75.400000           5.000000
# 75%    2022.000000            102.625000           7.000000
# max    2024.000000            130.000000           9.000000
#
#        battery_health_pct  motor_power_kw  vehicle_weight_kg  \
# count          845.000000      846.000000         819.000000
# mean            80.313609      386.212766        2555.907204
# std             11.687246      181.247452         774.757988
# min             60.000000       50.000000        1204.000000
# 25%             70.700000      235.250000        1934.000000
# 50%             80.500000      393.000000        2552.000000
# 75%             90.500000      544.000000        3188.500000
# max            100.000000      699.000000        3999.000000
#
#        drag_coefficient  ambient_temp_c  avg_speed_kmh  elevation_change_m  \
# count        832.000000      836.000000     823.000000          810.000000
# mean           0.347552       12.734569      76.818104            4.523951
# std            0.086873       18.657053      31.781272          287.708788
# min            0.200000      -20.000000      20.200000         -499.700000
# 25%            0.275000       -2.825000      50.450000         -238.450000
# 50%            0.345000       12.500000      76.700000           16.050000
# 75%            0.420000       29.000000     103.950000          250.050000
# max            0.500000       45.000000     130.000000          497.900000
#
#        num_passengers  cargo_weight_kg  wind_speed_kmh  actual_range_km
# count      832.000000       822.000000      836.000000       950.000000
# mean         3.551683       246.574209       40.158254       481.627102
# std          1.704308       140.318634       23.203074       656.342077
# min          1.000000         0.000000        0.100000        80.100000
# 25%          2.000000       128.000000       20.475000       243.400000
# 50%          4.000000       241.000000       40.100000       389.550000
# 75%          5.000000       365.750000       60.575000       558.350000
# max          6.000000       499.000000       79.700000      7158.274912

# %%
# dataset.info()
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   manufacturer          827 non-null    object
#  1   vehicle_type          830 non-null    object
#  2   charging_type_last    838 non-null    object
#  3   drive_config          836 non-null    object
#  4   battery_chemistry     822 non-null    object
#  5   model_year            828 non-null    float64
#  6   battery_capacity_kwh  828 non-null    float64
#  7   battery_age_years     846 non-null    float64
#  8   battery_health_pct    845 non-null    float64
#  9   motor_power_kw        846 non-null    float64
#  10  vehicle_weight_kg     819 non-null    float64
#  11  drag_coefficient      832 non-null    float64
#  12  tire_type             834 non-null    object
#  13  ambient_temp_c        836 non-null    float64
#  14  hvac_usage            705 non-null    object
#  15  avg_speed_kmh         823 non-null    float64
#  16  elevation_change_m    810 non-null    float64
#  17  num_passengers        832 non-null    float64
#  18  cargo_weight_kg       822 non-null    float64
#  19  regenerative_braking  841 non-null    object
#  20  driving_mode          829 non-null    object
#  21  wind_speed_kmh        836 non-null    float64
#  22  actual_range_km       950 non-null    float64
# dtypes: float64(14), object(9)
# memory usage: 170.8+ KB

# %%
# Cell: 07
#All numerical Columns
numerical_cols=dataset.select_dtypes(include=['int64','float64']).columns

# %%
# Cell: 08
dataset.shape
# Out:
# (950, 23)

# %%
# Cell: 09
numerical_cols
# Out:
# Index(['model_year', 'battery_capacity_kwh', 'battery_age_years',
#        'battery_health_pct', 'motor_power_kw', 'vehicle_weight_kg',
#        'drag_coefficient', 'ambient_temp_c', 'avg_speed_kmh',
#        'elevation_change_m', 'num_passengers', 'cargo_weight_kg',
#        'wind_speed_kmh', 'actual_range_km'],
#       dtype='object')

# %%
# Cell: 10
len(numerical_cols)
# Out:
# 14

# %%
# Cell: 11
#All categorical Columns
categorical_cols=dataset.select_dtypes(include='object').columns

# %%
# Cell: 12
categorical_cols
# Out:
# Index(['manufacturer', 'vehicle_type', 'charging_type_last', 'drive_config',
#        'battery_chemistry', 'tire_type', 'hvac_usage', 'regenerative_braking',
#        'driving_mode'],
#       dtype='object')

# %%
# Cell: 13
len(categorical_cols)
# Out:
# 9

# %%
# Cell: 14
dataset.dtypes
# Out:
# manufacturer             object
# vehicle_type             object
# charging_type_last       object
# drive_config             object
# battery_chemistry        object
#                          ...
# cargo_weight_kg         float64
# regenerative_braking     object
# driving_mode             object
# wind_speed_kmh          float64
# actual_range_km         float64
# Length: 23, dtype: object

# %%
# Cell: 15
dataset.isnull() #list All nulls
# Out:
#      manufacturer  vehicle_type  charging_type_last  drive_config  \
# 0           False          True               False         False
# 1           False         False               False         False
# 2           False         False               False         False
# 3           False         False               False         False
# 4           False         False                True         False
# ..            ...           ...                 ...           ...
# 945         False         False               False         False
# 946         False          True               False         False
# 947         False         False               False         False
# 948         False         False               False         False
# 949         False         False                True         False
#
#      battery_chemistry  model_year  battery_capacity_kwh  battery_age_years  \
# 0                False       False                 False               True
# 1                False       False                 False              False
# 2                False       False                 False              False
# 3                False       False                 False              False
# 4                False       False                 False               True
# ..                 ...         ...                   ...                ...
# 945              False       False                 False              False
# 946              False       False                 False              False
# 947              False       False                  True              False
# 948              False       False                 False              False
# 949              False       False                 False              False
#
#      battery_health_pct  motor_power_kw  vehicle_weight_kg  drag_coefficient  \
# 0                 False            True               True             False
# 1                 False           False              False             False
# 2                 False           False               True             False
# 3                 False            True              False             False
# 4                 False           False              False             False
# ..                  ...             ...                ...               ...
# 945               False           False              False             False
# 946               False           False              False             False
# 947               False           False              False             False
# 948               False           False              False             False
# 949               False           False              False             False
#
#      tire_type  ambient_temp_c  hvac_usage  avg_speed_kmh  elevation_change_m  \
# 0        False           False       False           True               False
# 1        False           False       False          False               False
# 2        False           False       False          False               False
# 3        False           False       False           True                True
# 4        False            True       False          False               False
# ..         ...             ...         ...            ...                 ...
# 945      False           False       False          False               False
# 946      False           False       False          False               False
# 947      False           False        True          False               False
# 948      False           False        True          False               False
# 949       True           False        True          False               False
#
#      num_passengers  cargo_weight_kg  regenerative_braking  driving_mode  \
# 0              True            False                 False         False
# 1             False            False                  True         False
# 2             False             True                 False         False
# 3             False            False                 False         False
# 4             False            False                 False         False
# ..              ...              ...                   ...           ...
# 945           False            False                 False         False
# 946           False            False                 False         False
# 947           False            False                  True         False
# 948           False            False                  True         False
# 949           False            False                 False         False
#
#      wind_speed_kmh  actual_range_km
# 0              True            False
# 1             False            False
# 2             False            False
# 3             False            False
# 4             False            False
# ..              ...              ...
# 945           False            False
# 946            True            False
# 947           False            False
# 948           False            False
# 949           False            False
#
# [950 rows x 23 columns]

# %%
# Cell: 16
dataset.isnull().values.any()   #any nulls available?
# Out:
# np.True_

# %%
# Cell: 17
dataset.isnull().values.sum()   #count all columns nulls
# Out:
# np.int64(2735)

# %%
# Cell: 18
dataset.isnull().sum()   #counts null in each columns
# Out:
# manufacturer            123
# vehicle_type            120
# charging_type_last      112
# drive_config            114
# battery_chemistry       128
#                        ...
# cargo_weight_kg         128
# regenerative_braking    109
# driving_mode            121
# wind_speed_kmh          114
# actual_range_km           0
# Length: 23, dtype: int64

# %%
# Cell: 19
dataset.shape
# Out:
# (950, 23)

# %%
# Cell: 20
# columns with null values
dataset.columns[dataset.isnull().any()]
# Out:
# Index(['manufacturer', 'vehicle_type', 'charging_type_last', 'drive_config',
#        'battery_chemistry', 'model_year', 'battery_capacity_kwh',
#        'battery_age_years', 'battery_health_pct', 'motor_power_kw',
#        'vehicle_weight_kg', 'drag_coefficient', 'tire_type', 'ambient_temp_c',
#        'hvac_usage', 'avg_speed_kmh', 'elevation_change_m', 'num_passengers',
#        'cargo_weight_kg', 'regenerative_braking', 'driving_mode',
#        'wind_speed_kmh'],
#       dtype='object')

# %%
# Cell: 21
len(dataset.columns[dataset.isnull().any()])
# Out:
# 22

# %%
# Cell: 22
plt.figure(figsize=(20,10))
sns.heatmap(dataset.isnull(),yticklabels=False,cbar=False,cmap='plasma')  #Set2, plasma, inferno, magma, cividis, Blues, Greens, Oranges, Reds
plt.show()

# %%
# Cell: 23
null_percentage=dataset.isnull().sum()/dataset.shape[0]*100

# %%
# Cell: 24
print(null_percentage)
# Out:
# manufacturer            12.947368
# vehicle_type            12.631579
# charging_type_last      11.789474
# drive_config            12.000000
# battery_chemistry       13.473684
#                           ...
# cargo_weight_kg         13.473684
# regenerative_braking    11.473684
# driving_mode            12.736842
# wind_speed_kmh          12.000000
# actual_range_km          0.000000
# Length: 23, dtype: float64

# %%
# Cell: 25
# columns to drop (more than 50% null values)
cols_to_drop = null_percentage[null_percentage > 50].keys()
cols_to_drop = null_percentage[null_percentage > 50]

# %%
# Cell: 26
cols_to_drop
# Out:
# Series([], dtype: float64)

# %%
# Cell: 27
cols_to_drop.keys() # no column to drop
# Out:
# Index([], dtype='object')

# %%
# Cell: 28
# check catagorical columns
dataset.select_dtypes(include='object').columns
# Out:
# Index(['manufacturer', 'vehicle_type', 'charging_type_last', 'drive_config',
#        'battery_chemistry', 'tire_type', 'hvac_usage', 'regenerative_braking',
#        'driving_mode'],
#       dtype='object')

# %%
# Cell: 29
# lenght of cat cols
len(dataset.select_dtypes(include = 'object').columns)
# Out:
# 9

# %%
# Cell: 30
dataset.select_dtypes(include=['int64','float64']).columns
# Out:
# Index(['model_year', 'battery_capacity_kwh', 'battery_age_years',
#        'battery_health_pct', 'motor_power_kw', 'vehicle_weight_kg',
#        'drag_coefficient', 'ambient_temp_c', 'avg_speed_kmh',
#        'elevation_change_m', 'num_passengers', 'cargo_weight_kg',
#        'wind_speed_kmh', 'actual_range_km'],
#       dtype='object')

# %%
# Cell: 31
numerical_cols[dataset.select_dtypes(include=['int64','float64']).isnull().any()]
# Out:
# Index(['model_year', 'battery_capacity_kwh', 'battery_age_years',
#        'battery_health_pct', 'motor_power_kw', 'vehicle_weight_kg',
#        'drag_coefficient', 'ambient_temp_c', 'avg_speed_kmh',
#        'elevation_change_m', 'num_passengers', 'cargo_weight_kg',
#        'wind_speed_kmh'],
#       dtype='object')

# %%
# Cell: 32
len(numerical_cols[dataset.select_dtypes(include=['int64','float64']).isnull().any()])
# Out:
# 13

# %%
# Cell: 33
#Place mean in the null places
dataset['model_year']=dataset['model_year'].fillna(dataset['model_year'].mean())

# %%
# Cell: 34
# fill while using a for loop--- convenient
null_num_cols=numerical_cols[dataset.select_dtypes(include=['int64','float64']).isnull().any()]

for col in null_num_cols:
    dataset[col]=dataset[col].fillna(dataset[col].mean())

# %%
# Cell: 35
# check num cols as null if 
numerical_cols[dataset.select_dtypes(include=['int64','float64']).isnull().any()]
# Out:
# Index([], dtype='object')

# %%
# Cell: 36
len(dataset.columns[dataset.isnull().any()]) # these are categorical columns
# Out:
# 9

# %% [markdown]
# # Add columns mode to categorical columns

# %%
# Cell: 37
dataset.select_dtypes(include='object').columns
# Out:
# Index(['manufacturer', 'vehicle_type', 'charging_type_last', 'drive_config',
#        'battery_chemistry', 'tire_type', 'hvac_usage', 'regenerative_braking',
#        'driving_mode'],
#       dtype='object')

# %%
len(dataset.select_dtypes(include='object').columns)
# Out:
# 9

# %%
# Cell: 38
dataset.columns[dataset.isnull().any()]  #categorical columns with nulls
# Out:
# Index(['manufacturer', 'vehicle_type', 'charging_type_last', 'drive_config',
#        'battery_chemistry', 'tire_type', 'hvac_usage', 'regenerative_braking',
#        'driving_mode'],
#       dtype='object')

# %%
# Cell: 39
len(dataset.columns[dataset.isnull().any()] )
# Out:
# 9

# %%
# Cell: 40
# fill while using mode 
dataset['manufacturer']=dataset['manufacturer'].fillna(dataset['manufacturer'].mode()[0])

# %%
#Cell: 41
# using for loop 
null_cat_cols=dataset.columns[dataset.isnull().any()]

for col in null_cat_cols:
    dataset[col]=dataset[col].fillna(dataset[col].mode()[0])

# %%
# Cell: 42
dataset['manufacturer'].mode()
# Out:
# 0    BYD
# Name: manufacturer, dtype: object

# %%
# Cell: 43
len(dataset.columns[dataset.isnull().any()]) #check nulls
# Out:
# 0

# %%
# Cell: 44
dataset.isnull().values.any()
# Out:
# np.False_

# %%
dataset.columns
# Out:
# Index(['manufacturer', 'vehicle_type', 'charging_type_last', 'drive_config',
#        'battery_chemistry', 'model_year', 'battery_capacity_kwh',
#        'battery_age_years', 'battery_health_pct', 'motor_power_kw',
#        'vehicle_weight_kg', 'drag_coefficient', 'tire_type', 'ambient_temp_c',
#        'hvac_usage', 'avg_speed_kmh', 'elevation_change_m', 'num_passengers',
#        'cargo_weight_kg', 'regenerative_braking', 'driving_mode',
#        'wind_speed_kmh', 'actual_range_km'],
#       dtype='object')

# %%
dataset.head()
# Out:
#   manufacturer vehicle_type charging_type_last drive_config battery_chemistry  \
# 0      Hyundai    Hatchback       Supercharger          FWD               LFP
# 1        Tesla   Sports Car           Wireless          AWD               NCA
# 2          BMW        Truck     DC Fast Charge          FWD       Solid State
# 3          NIO    Crossover           Wireless          AWD               NMC
# 4          NIO    Crossover       Supercharger          FWD               NMC
#
#    model_year  battery_capacity_kwh  battery_age_years  battery_health_pct  \
# 0      2024.0                  62.9           4.477541                98.3
# 1      2024.0                  49.9           2.000000                79.0
# 2      2015.0                  29.6           6.000000                73.0
# 3      2021.0                  65.5           2.000000                87.2
# 4      2021.0                 127.1           4.477541                78.9
#
#    motor_power_kw  vehicle_weight_kg  drag_coefficient  \
# 0      386.212766        2555.907204             0.305
# 1      679.000000        1455.000000             0.306
# 2      455.000000        2555.907204             0.329
# 3      386.212766        3812.000000             0.433
# 4      222.000000        1842.000000             0.434
#
#                 tire_type  ambient_temp_c hvac_usage  avg_speed_kmh  \
# 0  Low Rolling Resistance       38.100000   Max Heat      76.818104
# 1  Low Rolling Resistance       -6.800000   Max Heat      98.200000
# 2                Standard       13.700000    Heating     123.100000
# 3             All-Terrain       -1.600000   Max Cool      76.818104
# 4  Low Rolling Resistance       12.734569    Heating      55.300000
#
#    elevation_change_m  num_passengers  cargo_weight_kg regenerative_braking  \
# 0          349.900000        3.551683       270.000000                  Off
# 1          337.900000        1.000000       471.000000                  Off
# 2           65.700000        2.000000       246.574209                 High
# 3            4.523951        5.000000        45.000000                  Off
# 4         -248.000000        3.000000       169.000000                  Off
#
#   driving_mode  wind_speed_kmh  actual_range_km
# 0        Chill       40.158254            499.9
# 1        Chill       50.000000            328.2
# 2     Off-Road       60.500000            421.7
# 3        Sport       21.200000            647.8
# 4     Off-Road       39.000000            527.3

# %%
# Cell: 45
plt.figure(figsize = (16,9))
bar = sns.histplot(dataset['actual_range_km'], kde = True)
bar.legend(['actual_range_km: {:.2f}'.format(dataset['actual_range_km'].skew())])
plt.show()

# %%
# Cell: 46
dataset_2 = dataset.drop(columns = 'actual_range_km')

# %%
# Cell: 47
dataset_2.shape
# Out:
# (950, 22)

# %%
# Cell: 48
# feature–target relationship check
dataset_2.select_dtypes(include ='number').corrwith(dataset['actual_range_km']).plot.bar(
    figsize=(12,6), title = 'Correlated with actual_range_km', grid = True, colormap='coolwarm'
)
# Out:
# <Axes: title={'center': 'Correlated with actual_range_km'}>

# %%
# Cell: 49
dataset_2.select_dtypes(include ='number').corrwith(dataset['actual_range_km']).sort_values().plot.bar(
    figsize=(12,6), title = 'Correlated with actual_range_km', grid = True, colormap='coolwarm'
)
# Out:
# <Axes: title={'center': 'Correlated with actual_range_km'}>

# %%
# Cell: 50
#heatmap

plt.figure(figsize =(25, 25))
ax = sns.heatmap(data = dataset.select_dtypes(include ='number').corr(), cmap = 'coolwarm', annot= True, linewidth=2)

# %%
    # Cell: 51
high_corr = dataset.select_dtypes(include = 'number').corr()

# %%
# Cell: 52
high_corr_feetures = high_corr.index[abs(high_corr['actual_range_km']>0.02)]

# %%
# Cell: 53
high_corr_feetures
# Out:
# Index(['model_year', 'battery_health_pct', 'vehicle_weight_kg',
#        'num_passengers', 'cargo_weight_kg', 'actual_range_km'],
#       dtype='object')

# %%
# Cell: 54
len(high_corr_feetures)
# Out:
# 6

# %%
# Cell: 55
#heatmap
plt.figure(figsize =(10, 4))
ax = sns.heatmap(data = dataset[high_corr_feetures].select_dtypes(include ='number').corr(), cmap = 'coolwarm', annot= True, linewidth=2)

# %%
# Cell: 56
dataset.shape
# Out:
# (950, 74)

# %%
# Cell: 57
# list categorical columns
dataset.select_dtypes(include = 'object').columns
# Out:
# Index([], dtype='object')

# %%
# Cell: 58
dataset.head()
# Out:
#    model_year  battery_capacity_kwh  battery_age_years  battery_health_pct  \
# 0      2024.0                  62.9           4.477541                98.3
# 1      2024.0                  49.9           2.000000                79.0
# 2      2015.0                  29.6           6.000000                73.0
# 3      2021.0                  65.5           2.000000                87.2
# 4      2021.0                 127.1           4.477541                78.9
#
#    motor_power_kw  vehicle_weight_kg  drag_coefficient  ambient_temp_c  \
# 0      386.212766        2555.907204             0.305       38.100000
# 1      679.000000        1455.000000             0.306       -6.800000
# 2      455.000000        2555.907204             0.329       13.700000
# 3      386.212766        3812.000000             0.433       -1.600000
# 4      222.000000        1842.000000             0.434       12.734569
#
#    avg_speed_kmh  elevation_change_m  num_passengers  cargo_weight_kg  \
# 0      76.818104          349.900000        3.551683       270.000000
# 1      98.200000          337.900000        1.000000       471.000000
# 2     123.100000           65.700000        2.000000       246.574209
# 3      76.818104            4.523951        5.000000        45.000000
# 4      55.300000         -248.000000        3.000000       169.000000
#
#    wind_speed_kmh  actual_range_km  manufacturer_Audi  manufacturer_BMW  \
# 0       40.158254            499.9              False             False
# 1       50.000000            328.2              False             False
# 2       60.500000            421.7              False              True
# 3       21.200000            647.8              False             False
# 4       39.000000            527.3              False             False
#
#    manufacturer_BYD  manufacturer_BYD   manufacturer_HYUNDAI  \
# 0             False              False                 False
# 1             False              False                 False
# 2             False              False                 False
# 3             False              False                 False
# 4             False              False                 False
#
#    manufacturer_Hyundai  manufacturer_LUCID  manufacturer_Lucid  \
# 0                  True               False               False
# 1                 False               False               False
# 2                 False               False               False
# 3                 False               False               False
# 4                 False               False               False
#
#    manufacturer_NIO  manufacturer_NIO   manufacturer_POLESTAR  \
# 0             False              False                  False
# 1             False              False                  False
# 2             False              False                  False
# 3              True              False                  False
# 4              True              False                  False
#
#    manufacturer_Polestar  manufacturer_RIVIAN  manufacturer_Rivian  \
# 0                  False                False                False
# 1                  False                False                False
# 2                  False                False                False
# 3                  False                False                False
# 4                  False                False                False
#
#    manufacturer_TESLA  manufacturer_Tesla  manufacturer_VW  manufacturer_audi  \
# 0               False               False            False              False
# 1               False                True            False              False
# 2               False               False            False              False
# 3               False               False            False              False
# 4               False               False            False              False
#
#    manufacturer_bmw  manufacturer_byd  manufacturer_hyundai  \
# 0             False             False                 False
# 1             False             False                 False
# 2             False             False                 False
# 3             False             False                 False
# 4             False             False                 False
#
#    manufacturer_lucid  manufacturer_nio  manufacturer_polestar  \
# 0               False             False                  False
# 1               False             False                  False
# 2               False             False                  False
# 3               False             False                  False
# 4               False             False                  False
#
#    manufacturer_rivian  manufacturer_rivin  manufacturer_tesla  \
# 0                False               False               False
# 1                False               False               False
# 2                False               False               False
# 3                False               False               False
# 4                False               False               False
#
#    manufacturer_tesla   manufacturer_vw  vehicle_type_Hatchback  \
# 0                False            False                    True
# 1                False            False                   False
# 2                False            False                   False
# 3                False            False                   False
# 4                False            False                   False
#
#    vehicle_type_SUV  vehicle_type_Sedan  vehicle_type_Sports Car  \
# 0             False               False                    False
# 1             False               False                     True
# 2             False               False                    False
# 3             False               False                    False
# 4             False               False                    False
#
#    vehicle_type_Truck  vehicle_type_Van  charging_type_last_Level 1  \
# 0               False             False                       False
# 1               False             False                       False
# 2                True             False                       False
# 3               False             False                       False
# 4               False             False                       False
#
#    charging_type_last_Level 2  charging_type_last_Supercharger  \
# 0                       False                             True
# 1                       False                            False
# 2                       False                            False
# 3                       False                            False
# 4                       False                             True
#
#    charging_type_last_Wireless  drive_config_AWD  drive_config_FWD  \
# 0                        False             False              True
# 1                         True              True             False
# 2                        False             False              True
# 3                         True              True             False
# 4                        False             False              True
#
#    drive_config_RWD  battery_chemistry_NCA  battery_chemistry_NMC  \
# 0             False                  False                  False
# 1             False                   True                  False
# 2             False                  False                  False
# 3             False                  False                   True
# 4             False                  False                   True
#
#    battery_chemistry_NMCA  battery_chemistry_Solid State  \
# 0                   False                          False
# 1                   False                          False
# 2                   False                           True
# 3                   False                          False
# 4                   False                          False
#
#    tire_type_Low Rolling Resistance  tire_type_Performance  \
# 0                              True                  False
# 1                              True                  False
# 2                             False                  False
# 3                             False                  False
# 4                              True                  False
#
#    tire_type_Standard  hvac_usage_Heating  hvac_usage_Max Cool  \
# 0               False               False                False
# 1               False               False                False
# 2                True                True                False
# 3               False               False                 True
# 4               False                True                False
#
#    hvac_usage_Max Heat  regenerative_braking_Low  regenerative_braking_Max  \
# 0                 True                     False                     False
# 1                 True                     False                     False
# 2                False                     False                     False
# 3                False                     False                     False
# 4                False                     False                     False
#
#    regenerative_braking_Medium  regenerative_braking_Off  driving_mode_Eco  \
# 0                        False                      True             False
# 1                        False                      True             False
# 2                        False                     False             False
# 3                        False                      True             False
# 4                        False                      True             False
#
#    driving_mode_Normal  driving_mode_Off-Road  driving_mode_Sport
# 0                False                  False               False
# 1                False                  False               False
# 2                False                   True               False
# 3                False                  False                True
# 4                False                   True               False

# %%
num_cols=dataset.select_dtypes(include=['float64','int64']).columns

# %%
len(num_cols)
# Out:
# 14

# %%
cat_cols=dataset.select_dtypes(include='object').columns

# %%
len(cat_cols)
# Out:
# 0

# %%
# print(dataset['manufacturer'].nunique()) # individual
# using for loop
for col in cat_cols:
    print(col,':',dataset[col].nunique())

# %%
total_dummies=sum(dataset[col].nunique()-1 for col in cat_cols)
print(total_dummies)
# Out:
# 0

# %%
len(num_cols) # so total columns will be 74
# Out:
# 14

# %%
# Cell: 59
#is used to convert categorical/text columns into numerical columns because 
# Machine Learning models like Linear Regression cannot work with text data directly.
dataset = pd.get_dummies(data = dataset, drop_first = True)

# %%
# Cell: 60
dataset.shape
# Out:
# (950, 74)

# %%
# Cell: 61
dataset.head()
# Out:
#    model_year  battery_capacity_kwh  battery_age_years  battery_health_pct  \
# 0      2024.0                  62.9           4.477541                98.3
# 1      2024.0                  49.9           2.000000                79.0
# 2      2015.0                  29.6           6.000000                73.0
# 3      2021.0                  65.5           2.000000                87.2
# 4      2021.0                 127.1           4.477541                78.9
#
#    motor_power_kw  vehicle_weight_kg  drag_coefficient  ambient_temp_c  \
# 0      386.212766        2555.907204             0.305       38.100000
# 1      679.000000        1455.000000             0.306       -6.800000
# 2      455.000000        2555.907204             0.329       13.700000
# 3      386.212766        3812.000000             0.433       -1.600000
# 4      222.000000        1842.000000             0.434       12.734569
#
#    avg_speed_kmh  elevation_change_m  num_passengers  cargo_weight_kg  \
# 0      76.818104          349.900000        3.551683       270.000000
# 1      98.200000          337.900000        1.000000       471.000000
# 2     123.100000           65.700000        2.000000       246.574209
# 3      76.818104            4.523951        5.000000        45.000000
# 4      55.300000         -248.000000        3.000000       169.000000
#
#    wind_speed_kmh  actual_range_km  manufacturer_Audi  manufacturer_BMW  \
# 0       40.158254            499.9              False             False
# 1       50.000000            328.2              False             False
# 2       60.500000            421.7              False              True
# 3       21.200000            647.8              False             False
# 4       39.000000            527.3              False             False
#
#    manufacturer_BYD  manufacturer_BYD   manufacturer_HYUNDAI  \
# 0             False              False                 False
# 1             False              False                 False
# 2             False              False                 False
# 3             False              False                 False
# 4             False              False                 False
#
#    manufacturer_Hyundai  manufacturer_LUCID  manufacturer_Lucid  \
# 0                  True               False               False
# 1                 False               False               False
# 2                 False               False               False
# 3                 False               False               False
# 4                 False               False               False
#
#    manufacturer_NIO  manufacturer_NIO   manufacturer_POLESTAR  \
# 0             False              False                  False
# 1             False              False                  False
# 2             False              False                  False
# 3              True              False                  False
# 4              True              False                  False
#
#    manufacturer_Polestar  manufacturer_RIVIAN  manufacturer_Rivian  \
# 0                  False                False                False
# 1                  False                False                False
# 2                  False                False                False
# 3                  False                False                False
# 4                  False                False                False
#
#    manufacturer_TESLA  manufacturer_Tesla  manufacturer_VW  manufacturer_audi  \
# 0               False               False            False              False
# 1               False                True            False              False
# 2               False               False            False              False
# 3               False               False            False              False
# 4               False               False            False              False
#
#    manufacturer_bmw  manufacturer_byd  manufacturer_hyundai  \
# 0             False             False                 False
# 1             False             False                 False
# 2             False             False                 False
# 3             False             False                 False
# 4             False             False                 False
#
#    manufacturer_lucid  manufacturer_nio  manufacturer_polestar  \
# 0               False             False                  False
# 1               False             False                  False
# 2               False             False                  False
# 3               False             False                  False
# 4               False             False                  False
#
#    manufacturer_rivian  manufacturer_rivin  manufacturer_tesla  \
# 0                False               False               False
# 1                False               False               False
# 2                False               False               False
# 3                False               False               False
# 4                False               False               False
#
#    manufacturer_tesla   manufacturer_vw  vehicle_type_Hatchback  \
# 0                False            False                    True
# 1                False            False                   False
# 2                False            False                   False
# 3                False            False                   False
# 4                False            False                   False
#
#    vehicle_type_SUV  vehicle_type_Sedan  vehicle_type_Sports Car  \
# 0             False               False                    False
# 1             False               False                     True
# 2             False               False                    False
# 3             False               False                    False
# 4             False               False                    False
#
#    vehicle_type_Truck  vehicle_type_Van  charging_type_last_Level 1  \
# 0               False             False                       False
# 1               False             False                       False
# 2                True             False                       False
# 3               False             False                       False
# 4               False             False                       False
#
#    charging_type_last_Level 2  charging_type_last_Supercharger  \
# 0                       False                             True
# 1                       False                            False
# 2                       False                            False
# 3                       False                            False
# 4                       False                             True
#
#    charging_type_last_Wireless  drive_config_AWD  drive_config_FWD  \
# 0                        False             False              True
# 1                         True              True             False
# 2                        False             False              True
# 3                         True              True             False
# 4                        False             False              True
#
#    drive_config_RWD  battery_chemistry_NCA  battery_chemistry_NMC  \
# 0             False                  False                  False
# 1             False                   True                  False
# 2             False                  False                  False
# 3             False                  False                   True
# 4             False                  False                   True
#
#    battery_chemistry_NMCA  battery_chemistry_Solid State  \
# 0                   False                          False
# 1                   False                          False
# 2                   False                           True
# 3                   False                          False
# 4                   False                          False
#
#    tire_type_Low Rolling Resistance  tire_type_Performance  \
# 0                              True                  False
# 1                              True                  False
# 2                             False                  False
# 3                             False                  False
# 4                              True                  False
#
#    tire_type_Standard  hvac_usage_Heating  hvac_usage_Max Cool  \
# 0               False               False                False
# 1               False               False                False
# 2                True                True                False
# 3               False               False                 True
# 4               False                True                False
#
#    hvac_usage_Max Heat  regenerative_braking_Low  regenerative_braking_Max  \
# 0                 True                     False                     False
# 1                 True                     False                     False
# 2                False                     False                     False
# 3                False                     False                     False
# 4                False                     False                     False
#
#    regenerative_braking_Medium  regenerative_braking_Off  driving_mode_Eco  \
# 0                        False                      True             False
# 1                        False                      True             False
# 2                        False                     False             False
# 3                        False                      True             False
# 4                        False                      True             False
#
#    driving_mode_Normal  driving_mode_Off-Road  driving_mode_Sport
# 0                False                  False               False
# 1                False                  False               False
# 2                False                   True               False
# 3                False                  False                True
# 4                False                   True               False

# %%
# Cell: 58
# list categorical columns
dataset.select_dtypes(include = 'object').columns
# Out:
# Index([], dtype='object')

# %%
# Cell: 59
len(dataset.select_dtypes(include = 'object').columns)
# Out:
# 0

# %%
# Cell: 60
dataset.head()
# Out:
#    model_year  battery_capacity_kwh  battery_age_years  battery_health_pct  \
# 0      2024.0                  62.9           4.477541                98.3
# 1      2024.0                  49.9           2.000000                79.0
# 2      2015.0                  29.6           6.000000                73.0
# 3      2021.0                  65.5           2.000000                87.2
# 4      2021.0                 127.1           4.477541                78.9
#
#    motor_power_kw  vehicle_weight_kg  drag_coefficient  ambient_temp_c  \
# 0      386.212766        2555.907204             0.305       38.100000
# 1      679.000000        1455.000000             0.306       -6.800000
# 2      455.000000        2555.907204             0.329       13.700000
# 3      386.212766        3812.000000             0.433       -1.600000
# 4      222.000000        1842.000000             0.434       12.734569
#
#    avg_speed_kmh  elevation_change_m  num_passengers  cargo_weight_kg  \
# 0      76.818104          349.900000        3.551683       270.000000
# 1      98.200000          337.900000        1.000000       471.000000
# 2     123.100000           65.700000        2.000000       246.574209
# 3      76.818104            4.523951        5.000000        45.000000
# 4      55.300000         -248.000000        3.000000       169.000000
#
#    wind_speed_kmh  actual_range_km  manufacturer_Audi  manufacturer_BMW  \
# 0       40.158254            499.9              False             False
# 1       50.000000            328.2              False             False
# 2       60.500000            421.7              False              True
# 3       21.200000            647.8              False             False
# 4       39.000000            527.3              False             False
#
#    manufacturer_BYD  manufacturer_BYD   manufacturer_HYUNDAI  \
# 0             False              False                 False
# 1             False              False                 False
# 2             False              False                 False
# 3             False              False                 False
# 4             False              False                 False
#
#    manufacturer_Hyundai  manufacturer_LUCID  manufacturer_Lucid  \
# 0                  True               False               False
# 1                 False               False               False
# 2                 False               False               False
# 3                 False               False               False
# 4                 False               False               False
#
#    manufacturer_NIO  manufacturer_NIO   manufacturer_POLESTAR  \
# 0             False              False                  False
# 1             False              False                  False
# 2             False              False                  False
# 3              True              False                  False
# 4              True              False                  False
#
#    manufacturer_Polestar  manufacturer_RIVIAN  manufacturer_Rivian  \
# 0                  False                False                False
# 1                  False                False                False
# 2                  False                False                False
# 3                  False                False                False
# 4                  False                False                False
#
#    manufacturer_TESLA  manufacturer_Tesla  manufacturer_VW  manufacturer_audi  \
# 0               False               False            False              False
# 1               False                True            False              False
# 2               False               False            False              False
# 3               False               False            False              False
# 4               False               False            False              False
#
#    manufacturer_bmw  manufacturer_byd  manufacturer_hyundai  \
# 0             False             False                 False
# 1             False             False                 False
# 2             False             False                 False
# 3             False             False                 False
# 4             False             False                 False
#
#    manufacturer_lucid  manufacturer_nio  manufacturer_polestar  \
# 0               False             False                  False
# 1               False             False                  False
# 2               False             False                  False
# 3               False             False                  False
# 4               False             False                  False
#
#    manufacturer_rivian  manufacturer_rivin  manufacturer_tesla  \
# 0                False               False               False
# 1                False               False               False
# 2                False               False               False
# 3                False               False               False
# 4                False               False               False
#
#    manufacturer_tesla   manufacturer_vw  vehicle_type_Hatchback  \
# 0                False            False                    True
# 1                False            False                   False
# 2                False            False                   False
# 3                False            False                   False
# 4                False            False                   False
#
#    vehicle_type_SUV  vehicle_type_Sedan  vehicle_type_Sports Car  \
# 0             False               False                    False
# 1             False               False                     True
# 2             False               False                    False
# 3             False               False                    False
# 4             False               False                    False
#
#    vehicle_type_Truck  vehicle_type_Van  charging_type_last_Level 1  \
# 0               False             False                       False
# 1               False             False                       False
# 2                True             False                       False
# 3               False             False                       False
# 4               False             False                       False
#
#    charging_type_last_Level 2  charging_type_last_Supercharger  \
# 0                       False                             True
# 1                       False                            False
# 2                       False                            False
# 3                       False                            False
# 4                       False                             True
#
#    charging_type_last_Wireless  drive_config_AWD  drive_config_FWD  \
# 0                        False             False              True
# 1                         True              True             False
# 2                        False             False              True
# 3                         True              True             False
# 4                        False             False              True
#
#    drive_config_RWD  battery_chemistry_NCA  battery_chemistry_NMC  \
# 0             False                  False                  False
# 1             False                   True                  False
# 2             False                  False                  False
# 3             False                  False                   True
# 4             False                  False                   True
#
#    battery_chemistry_NMCA  battery_chemistry_Solid State  \
# 0                   False                          False
# 1                   False                          False
# 2                   False                           True
# 3                   False                          False
# 4                   False                          False
#
#    tire_type_Low Rolling Resistance  tire_type_Performance  \
# 0                              True                  False
# 1                              True                  False
# 2                             False                  False
# 3                             False                  False
# 4                              True                  False
#
#    tire_type_Standard  hvac_usage_Heating  hvac_usage_Max Cool  \
# 0               False               False                False
# 1               False               False                False
# 2                True                True                False
# 3               False               False                 True
# 4               False                True                False
#
#    hvac_usage_Max Heat  regenerative_braking_Low  regenerative_braking_Max  \
# 0                 True                     False                     False
# 1                 True                     False                     False
# 2                False                     False                     False
# 3                False                     False                     False
# 4                False                     False                     False
#
#    regenerative_braking_Medium  regenerative_braking_Off  driving_mode_Eco  \
# 0                        False                      True             False
# 1                        False                      True             False
# 2                        False                     False             False
# 3                        False                      True             False
# 4                        False                      True             False
#
#    driving_mode_Normal  driving_mode_Off-Road  driving_mode_Sport
# 0                False                  False               False
# 1                False                  False               False
# 2                False                   True               False
# 3                False                  False                True
# 4                False                   True               False

# %%
corr = dataset.corr(numeric_only=True)['actual_range_km'].abs()

strong_features = corr[corr > 0.2].index
strong_features
# Out:
# Index(['actual_range_km'], dtype='object')

# %% [markdown]
# # Splitting the dataset

# %%
# Cell: 61
# independ variables / matrix of features
x = dataset.drop(columns = 'actual_range_km')

# %%
# Cell: 62
# target variables / dependent variable
y = dataset['actual_range_km']

# %%
#pip install scikit-learn

# %%
# Cell: 63
from sklearn.model_selection import train_test_split

# %%
# Cell: 64
x_train ,x_test, y_train, y_test  = train_test_split(x, y, test_size=0.2 , random_state=0)

# %%
# Cell: 65
x_train.shape
# Out:
# (760, 73)

# %%
# Cell: 66
y_train.shape
# Out:
# (760,)

# %%
# Cell: 67
x_test.shape
# Out:
# (190, 73)

# %%
# Cell: 68
y_test.shape
# Out:
# (190,)

# %%
# Cell: 69
# feature scaling - 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
# Cell: 70
x_train
# Out:
# array([[-0.54981849, -1.29366726, -0.53932676, ..., -0.46056619,
#         -0.44367825, -0.67523233],
#        [ 0.92883192,  0.38673849, -0.90124433, ..., -0.46056619,
#         -0.44367825,  1.48097175],
#        [ 0.55916932,  0.3296047 , -0.53932676, ..., -0.46056619,
#          2.25388553, -0.67523233],
#        ...,
#        [ 1.29849453, -1.12898749,  1.27026111, ..., -0.46056619,
#          2.25388553, -0.67523233],
#        [ 0.00780058,  0.54133582,  0.18450839, ..., -0.46056619,
#         -0.44367825,  1.48097175],
#        [-1.6588063 , -1.49195513, -1.2631619 , ..., -0.46056619,
#         -0.44367825, -0.67523233]], shape=(760, 73))

# %%
# Cell: 71
from sklearn.linear_model import LinearRegression

# %%
# Cell: 72
regressor_mlr = LinearRegression()
regressor_mlr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Cell: 73
y_pred = regressor_mlr.predict(x_test)

# %%
# Cell: 74
from sklearn.metrics import r2_score

# %%
# Cell: 75
r2_score(y_test, y_pred)
# Out:
# -0.4039498892373836

# %%
# Note:
# No strong linear relationship was found between independent variables 
# and target variable using correlation analysis. Therefore, Linear Regression 
# shows limited performance because the dataset contains non-linear relationships.
