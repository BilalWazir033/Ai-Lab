# %%
print("My World")
# Out:
# My World

# %%
if 10>5:
    print("I will be your friend")
    if 20>40:
        print("I am your boy")
print("1st if")

# dasae zar
"""
i am your 
friend
"""
# Out:
# I will be your friend
# 1st if
# '\ni am your \nfriend\n'

# %%
a=20
b="Jan"
c=13
print(type(a),type(b),type(c))
# Out:
# <class 'int'> <class 'str'> <class 'int'>

# %%
_name="Imran"
name_Wahid=12
name9age= 23
name="Waheed"
name_salar=23
# Out:
#   Cell In[27], line 5
#     name-salar=23
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
x,y,z=23,45,65
print(y)
x=y=z=45
print(z)
a=b=c=23
print(a)
# Out:
# 45
# 45
# 23

# %%
name=(input("Enter your name:"))
print("My name is: ",name)
print(type(name))
# Out:
# Enter your name: khlaida
# My name is:  khlaida
# <class 'str'>

# %%
def addition(a,b):
    return a+b
result=addition(23,453)
print(result)
sum=12+34
print(sum)
# Out:
# 476
# 46

# %%
c=223+45j
print(c)
# Out:
# (223+45j)

# %%
fruit="Apple is my farioute fruit"
print(fruit)
fruit="""
apple is 
my 
favrioute fruit
"""
print(fruit)
# Out:
# Apple is my farioute fruit
#
# apple is
# my
# favrioute fruit

# %%
fruits="a222apl1sss1ee"
print(fruits[1:4])

print(len(fruits))
# Out:
# 222
# 14

# %%
fruit="apple is my favrioute fruit"
if "my" in fruit:
    print("yes")

else:
    print("NO")
# Out:
# yes

# %%
a="Wolrd"
print(a[-3:-1])
# Out:
# lr

# %%
fruit="apple is my favrioOUte fruit"
print(fruit.upper())
print(fruit.lower())
# Out:
# APPLE IS MY FAVRIOOUTE FRUIT
# apple is my favriooute fruit

# %%
fruit="          apple is my favrioOUte fruit        "
print(fruit)
print(fruit.replace(" ",""))
print(fruit.strip())
print(fruit.replace("fruit", "vegitable"))
# Out:
#           apple is my favrioOUte fruit
# appleismyfavrioOUtefruit
# apple is my favrioOUte fruit
#           apple is my favrioOUte vegitable
