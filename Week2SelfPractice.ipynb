# %%
pip install numpy
# Out:
# File contains parsing errors:
# 	[line  2]: pip install numpy
#
# Invalid statements: SyntaxError('invalid syntax', ('<string>', 1, 5, 'pip install numpy\n', 1, 12))

# %%
import numpy as np

# %%
arr= np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]
